# %% [markdown]
# <a href="https://colab.research.google.com/github/maztig/Machine-Learning/blob/main/BreastCancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import and Analysis**

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
for x in df.columns:
  print(x)
  print("---------------------------------")
# Out:
# id
# ---------------------------------
# diagnosis
# ---------------------------------
# radius_mean
# ---------------------------------
# texture_mean
# ---------------------------------
# perimeter_mean
# ---------------------------------
# area_mean
# ---------------------------------
# smoothness_mean
# ---------------------------------
# compactness_mean
# ---------------------------------
# concavity_mean
# ---------------------------------
# concave points_mean
# ---------------------------------
# symmetry_mean
# ---------------------------------
# fractal_dimension_mean
# ---------------------------------
# radius_se
# ---------------------------------
# texture_se
# ---------------------------------
# perimeter_se
# ---------------------------------
# area_se
# ---------------------------------
# smoothness_se
# ---------------------------------
# compactness_se
# ---------------------------------
# concavity_se
# ---------------------------------
# concave points_se
# ...

# %% [markdown]
# # **Data manipulation**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(df, test_size=0.2)

# %%
model = RandomForestClassifier()

# %%
train_X = train_df.drop("diagnosis", axis=1)
train_Y = train_df["diagnosis"]

test_X = test_df.drop("diagnosis", axis=1)
test_Y = test_df["diagnosis"]

# %% [markdown]
# # **Training and Testing**

# %%
model.fit(train_X, train_Y)
# Out:
# RandomForestClassifier()

# %%
model.score(test_X, test_Y)
# Out:
# 0.9649122807017544

# %%
importances = dict(zip(model.feature_names_in_, model.feature_importances_))
importances = {k: v for k, v in sorted(importances.items(), key = lambda x: x[1], reverse=True)}

# %%
importances
# Out:
# {'radius_worst': 0.14638169169015422,
#  'concave points_worst': 0.11811269126814113,
#  'area_worst': 0.11094765129098158,
#  'perimeter_worst': 0.10462858972437326,
#  'concave points_mean': 0.10197760044116962,
#  'concavity_mean': 0.06486790591381321,
#  'radius_mean': 0.04792940305237265,
#  'concavity_worst': 0.045491676287247096,
#  'area_se': 0.03576848043712892,
#  'area_mean': 0.02792894238416234,
#  'perimeter_mean': 0.026855109560274842,
#  'texture_worst': 0.02340229190912563,
#  'texture_mean': 0.019476109358479356,
#  'radius_se': 0.01693438353512542,
#  'compactness_mean': 0.014595269611814586,
#  'compactness_worst': 0.012797862651339814,
#  'symmetry_worst': 0.010669254192426557,
#  'perimeter_se': 0.010580447487279848,
#  'smoothness_worst': 0.009051704853895406,
#  'fractal_dimension_worst': 0.00725747281527795,
#  'concavity_se': 0.00483787911714133,
#  'texture_se': 0.004721812202302133,
#  'id': 0.004693648316388586,
# ...
